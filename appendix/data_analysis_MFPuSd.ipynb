# %% [markdown]
# https://www.kaggle.com/datasets/umerrtx/machine-failure-prediction-using-sensor-data/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'myenv (Python 3.11.3)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df = pd.read_csv('datasets/MFPuSd/data.csv')

# %%
df.head()

# %%
print(f"AI4I:")
print(f"--------------------------------")
print(f"Shape: {df.shape}\n")
print(f"Columns: {df.columns}\n")
print(f"Count: {df['fail'].value_counts()}\n")
print(f"Products: {df['footfall'].unique()}\n")
print(f"Unique per column: {df.nunique()}\n")

# %%
sns.pairplot(df, hue='fail')
plt.show()
